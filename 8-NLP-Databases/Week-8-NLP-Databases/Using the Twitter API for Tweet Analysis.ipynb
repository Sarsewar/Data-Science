# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
#!pip install twitter
#python -m pip install --upgrade pip

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x000001FF501EE6D8>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [India](http://woeid.rosselliot.co.nz/lookup/India)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=23424848

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'as_of': '2018-06-09T09:42:20Z',
#   'created_at': '2018-06-09T09:37:07Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}],
#   'trends': [{'name': '#NZLvFRA',
#     'promoted_content': None,
#     'query': '%23NZLvFRA',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23NZLvFRA'},
#    {'name': '#FakeLove11thWin',
#     'promoted_content': None,
#     'query': '%23FakeLove11thWin',
#     'tweet_volume': 216523,
#     'url': 'http://twitter.com/search?q=%23FakeLove11thWin'},
#    {'name': '#njdominion',
#     'promoted_content': None,
#     'query': '%23njdominion',
#     'tweet_volume': 34719,
#     'url': 'http://twitter.com/search?q=%23njdominion'},
#    {'name': '#FelizSábado',
#     'promoted_content': None,
#     'query': '%23FelizS%C3%A1bado',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23FelizS%C3%A1bado'},
#    {'name': '#اقدر_الان_اقول',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%82%D8%AF%D8%B1_%D8%A7%D9%84%D8%A7%D9%86_%D8%A7%D9%82%D9%88%D9%84',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%82%D8%AF%D8%B1_%D8%A7%D9%84%D8%A7%D9%86_%D8%A7%D9%82%D9%88%D9%84'},
#    {'name': '사전투표',
#     'promoted_content': None,
#     'query': '%EC%82%AC%EC%A0%84%ED%88%AC%ED%91%9C',
#     'tweet_volume': 292331,
#     'url': 'http://twitter.com/search?q=%EC%82%AC%EC%A0%84%ED%88%AC%ED%91%9C'},
#    {'name': 'Ravi Pujari',
#     'promoted_content': None,
#     'query': '%22Ravi+Pujari%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Ravi+Pujari%22'},
#    {'name': 'ミュージックフェア',
#     'promoted_content': None,
#     'query': '%E3%83%9F%E3%83%A5%E3%83%BC%E3%82%B8%E3%83%83%E3%82%AF%E3%83%95%E3%82%A7%E3%82%A2',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%E3%83%9F%E3%83%A5%E3%83%BC%E3%82%B8%E3%83%83%E3%82%AF%E3%83%95%E3%82%A7%E3%82%A2'},
#    {'name': 'MUSIC FAIR',
#     'promoted_content': None,
#     'query': '%22MUSIC+FAIR%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22MUSIC+FAIR%22'},
#    {'name': '혜화역',
#     'promoted_content': None,
#     'query': '%ED%98%9C%ED%99%94%EC%97%AD',
#     'tweet_volume': 10731,
#     'url': 'http://twitter.com/search?q=%ED%98%9C%ED%99%94%EC%97%AD'},
#    {'name': '能見さん',
#     'promoted_content': None,
#     'query': '%E8%83%BD%E8%A6%8B%E3%81%95%E3%82%93',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%E8%83%BD%E8%A6%8B%E3%81%95%E3%82%93'},
#    {'name': 'Swaggy P',
#     'promoted_content': None,
#     'query': '%22Swaggy+P%22',
#     'tweet_volume': 39608,
#     'url': 'http://twitter.com/search?q=%22Swaggy+P%22'},
#    {'name': 'ドリス',
#     'promoted_content': None,
#     'query': '%E3%83%89%E3%83%AA%E3%82%B9',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%E3%83%89%E3%83%AA%E3%82%B9'},
#    {'name': '최코테',
#     'promoted_content': None,
#     'query': '%EC%B5%9C%EC%BD%94%ED%85%8C',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%EC%B5%9C%EC%BD%94%ED%85%8C'},
#    {'name': 'Northcote',
#     'promoted_content': None,
#     'query': 'Northcote',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Northcote'},
#    {'name': '#AFLGiantsSuns',
#     'promoted_content': None,
#     'query': '%23AFLGiantsSuns',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23AFLGiantsSuns'},
#    {'name': '#혜화시위',
#     'promoted_content': None,
#     'query': '%23%ED%98%9C%ED%99%94%EC%8B%9C%EC%9C%84',
#     'tweet_volume': 70526,
#     'url': 'http://twitter.com/search?q=%23%ED%98%9C%ED%99%94%EC%8B%9C%EC%9C%84'},
#    {'name': '#DíadelaRegióndeMurcia',
#     'promoted_content': None,
#     'query': '%23D%C3%ADadelaRegi%C3%B3ndeMurcia',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23D%C3%ADadelaRegi%C3%B3ndeMurcia'},
#    {'name': '#cumartesi',
#     'promoted_content': None,
#     'query': '%23cumartesi',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23cumartesi'},
#    {'name': '#QueensBirthdayHonours',
#     'promoted_content': None,
#     'query': '%23QueensBirthdayHonours',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23QueensBirthdayHonours'},
#    {'name': '#ロックの日',
#     'promoted_content': None,
#     'query': '%23%E3%83%AD%E3%83%83%E3%82%AF%E3%81%AE%E6%97%A5',
#     'tweet_volume': 57170,
#     'url': 'http://twitter.com/search?q=%23%E3%83%AD%E3%83%83%E3%82%AF%E3%81%AE%E6%97%A5'},
#    {'name': '#TEDxKakumaCamp',
#     'promoted_content': None,
#     'query': '%23TEDxKakumaCamp',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23TEDxKakumaCamp'},
#    {'name': '#NRLKnightsRoosters',
#     'promoted_content': None,
#     'query': '%23NRLKnightsRoosters',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23NRLKnightsRoosters'},
#    {'name': '#9HaziranDünyaDuaGünü',
#     'promoted_content': None,
#     'query': '%239HaziranD%C3%BCnyaDuaG%C3%BCn%C3%BC',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%239HaziranD%C3%BCnyaDuaG%C3%BCn%C3%BC'},
#    {'name': '#HappyBirthdaySonamKapoor',
#     'promoted_content': None,
#     'query': '%23HappyBirthdaySonamKapoor',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23HappyBirthdaySonamKapoor'},
#    {'name': '#نخبه_العود_مرسيدس17',
#     'promoted_content': None,
#     'query': '%23%D9%86%D8%AE%D8%A8%D9%87_%D8%A7%D9%84%D8%B9%D9%88%D8%AF_%D9%85%D8%B1%D8%B3%D9%8A%D8%AF%D8%B317',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D9%86%D8%AE%D8%A8%D9%87_%D8%A7%D9%84%D8%B9%D9%88%D8%AF_%D9%85%D8%B1%D8%B3%D9%8A%D8%AF%D8%B317'},
#    {'name': '#WorldGinDay',
#     'promoted_content': None,
#     'query': '%23WorldGinDay',
#     'tweet_volume': 14986,
#     'url': 'http://twitter.com/search?q=%23WorldGinDay'},
#    {'name': '#TroopingtheColour',
#     'promoted_content': None,
#     'query': '%23TroopingtheColour',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23TroopingtheColour'},
#    {'name': '#WannaOne1TheWorldinBKK',
#     'promoted_content': None,
#     'query': '%23WannaOne1TheWorldinBKK',
#     'tweet_volume': 2008593,
#     'url': 'http://twitter.com/search?q=%23WannaOne1TheWorldinBKK'},
#    {'name': '#Paris7s',
#     'promoted_content': None,
#     'query': '%23Paris7s',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Paris7s'},
#    {'name': '#SaturdayKitchen',
#     'promoted_content': None,
#     'query': '%23SaturdayKitchen',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23SaturdayKitchen'},
#    {'name': '#NUBantulCINTARumi',
#     'promoted_content': None,
#     'query': '%23NUBantulCINTARumi',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23NUBantulCINTARumi'},
#    {'name': '#N1CanalFiesta23',
#     'promoted_content': None,
#     'query': '%23N1CanalFiesta23',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23N1CanalFiesta23'},
#    {'name': '#AFLSaintsSwans',
#     'promoted_content': None,
#     'query': '%23AFLSaintsSwans',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23AFLSaintsSwans'},
#    {'name': '#아무것도몰랐던_사퍼_뉴비시절',
#     'promoted_content': None,
#     'query': '%23%EC%95%84%EB%AC%B4%EA%B2%83%EB%8F%84%EB%AA%B0%EB%9E%90%EB%8D%98_%EC%82%AC%ED%8D%BC_%EB%89%B4%EB%B9%84%EC%8B%9C%EC%A0%88',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%EC%95%84%EB%AC%B4%EA%B2%83%EB%8F%84%EB%AA%B0%EB%9E%90%EB%8D%98_%EC%82%AC%ED%8D%BC_%EB%89%B4%EB%B9%84%EC%8B%9C%EC%A0%88'},
#    {'name': '#rEDRugby',
#     'promoted_content': None,
#     'query': '%23rEDRugby',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23rEDRugby'},
#    {'name': '#9giugno',
#     'promoted_content': None,
#     'query': '%239giugno',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%239giugno'},
#    {'name': '#PESBUKERSRAMADANANTV25',
#     'promoted_content': None,
#     'query': '%23PESBUKERSRAMADANANTV25',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23PESBUKERSRAMADANANTV25'},
#    {'name': '#QUINTET',
#     'promoted_content': None,
#     'query': '%23QUINTET',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23QUINTET'},
#    {'name': '#LibrosConPiernas',
#     'promoted_content': None,
#     'query': '%23LibrosConPiernas',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23LibrosConPiernas'},
#    {'name': '#IAD18',
#     'promoted_content': None,
#     'query': '%23IAD18',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23IAD18'},
#    {'name': '#ALDUBMusicOfOurHearts',
#     'promoted_content': None,
#     'query': '%23ALDUBMusicOfOurHearts',
#     'tweet_volume': 672170,
#     'url': 'http://twitter.com/search?q=%23ALDUBMusicOfOurHearts'},
#    {'name': '#BanggaIndonesia',
#     'promoted_content': None,
#     'query': '%23BanggaIndonesia',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23BanggaIndonesia'},
#    {'name': '#loveparkrun',
#     'promoted_content': None,
#     'query': '%23loveparkrun',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23loveparkrun'},
#    {'name': '#PertaminaBareng2Mudik2018',
#     'promoted_content': None,
#     'query': '%23PertaminaBareng2Mudik2018',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23PertaminaBareng2Mudik2018'},
#    {'name': '#ロック好きにしか解けないクイズ',
#     'promoted_content': None,
#     'query': '%23%E3%83%AD%E3%83%83%E3%82%AF%E5%A5%BD%E3%81%8D%E3%81%AB%E3%81%97%E3%81%8B%E8%A7%A3%E3%81%91%E3%81%AA%E3%81%84%E3%82%AF%E3%82%A4%E3%82%BA',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%E3%83%AD%E3%83%83%E3%82%AF%E5%A5%BD%E3%81%8D%E3%81%AB%E3%81%97%E3%81%8B%E8%A7%A3%E3%81%91%E3%81%AA%E3%81%84%E3%82%AF%E3%82%A4%E3%82%BA'},
#    {'name': '#NotOurLastHunt',
#     'promoted_content': None,
#     'query': '%23NotOurLastHunt',
#     'tweet_volume': 34299,
#     'url': 'http://twitter.com/search?q=%23NotOurLastHunt'},
#    {'name': '#vvkorea_309',
#     'promoted_content': None,
#     'query': '%23vvkorea_309',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23vvkorea_309'},
#    {'name': '#ViratBeardInsurance',
#     'promoted_content': None,
#     'query': '%23ViratBeardInsurance',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ViratBeardInsurance'},
#    {'name': '#GoldenStateWarriors',
#     'promoted_content': None,
#     'query': '%23GoldenStateWarriors',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23GoldenStateWarriors'}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#HappyBirthdaySonamKapoor', 'url': 'http://twitter.com/search?q=%23HappyBirthdaySonamKapoor', 'promoted_content': None, 'query': '%23HappyBirthdaySonamKapoor', 'tweet_volume': None}, {'name': 'Ravi Pujari', 'url': 'http://twitter.com/search?q=%22Ravi+Pujari%22', 'promoted_content': None, 'query': '%22Ravi+Pujari%22', 'tweet_volume': None}, {'name': '#ViratBeardInsurance', 'url': 'http://twitter.com/search?q=%23ViratBeardInsurance', 'promoted_content': None, 'query': '%23ViratBeardInsurance', 'tweet_volume': None}, {'name': 'Rajesh Bharti', 'url': 'http://twitter.com/search?q=%22Rajesh+Bharti%22', 'promoted_content': None, 'query': '%22Rajesh+Bharti%22', 'tweet_volume': None}, {'name': '#KuppathuRaja', 'url': 'http://twitter.com/search?q=%23KuppathuRaja', 'promoted_content': None, 'query': '%23KuppathuRaja', 'tweet_volume': None}, {'name': '#INDvPAK', 'url': 'http://twitter.com/search?q=%23INDvPAK', 'promoted_content': None, 'query': '%23INDvPAK', 'tweet_volume': None}, {'name': '#Qingdao', 'url': 'http://twitter.com/search?q=%23Qingdao', 'promoted_content': None, 'query': '%23Qingdao', 'tweet_volume': None}, {'name': 'Umar Khalid', 'url': 'http://twitter.com/search?q=%22Umar+Khalid%22', 'promoted_content': None, 'query': '%22Umar+Khalid%22', 'tweet_volume': None}, {'name': 'Rs 4.5', 'url': 'http://twitter.com/search?q=%22Rs+4.5%22', 'promoted_content': None, 'query': '%22Rs+4.5%22', 'tweet_volume': None}, {'name': 'बिरसा मुंडा', 'url': 'http://twitter.com/search?q=%22%E0%A4%AC%E0%A4%BF%E0%A4%B0%E0%A4%B8%E0%A4%BE+%E0%A4%AE%E0%A5%81%E0%A4%82%E0%A4%A1%E0%A4%BE%22', 'promoted_content': None, 'query': '%22%E0%A4%AC%E0%A4%BF%E0%A4%B0%E0%A4%B8%E0%A4%BE+%E0%A4%AE%E0%A5%81%E0%A4%82%E0%A4%A1%E0%A4%BE%22', 'tweet_volume': 12132}, {'name': 'Sonia Gandhi', 'url': 'http://twitter.com/search?q=%22Sonia+Gandhi%22', 'promoted_content': None, 'query': '%22Sonia+Gandhi%22', 'tweet_volume': None}, {'name': 'Shantaram Naik', 'url': 'http://twitter.com/search?q=%22Shantaram+Naik%22', 'promoted_content': None, 'query': '%22Shantaram+Naik%22', 'tweet_volume': None}, {'name': 'Maria Bueno', 'url': 'http://twitter.com/search?q=%22Maria+Bueno%22', 'promoted_content': None, 'query': '%22Maria+Bueno%22', 'tweet_volume': None}, {'name': '#SaturdayMotivation', 'url': 'http://twitter.com/search?q=%23SaturdayMotivation', 'promoted_content': None, 'query': '%23SaturdayMotivation', 'tweet_volume': 15793}, {'name': '#NaaNuvve', 'url': 'http://twitter.com/search?q=%23NaaNuvve', 'promoted_content': None, 'query': '%23NaaNuvve', 'tweet_volume': None}, {'name': '#AskTeesta', 'url': 'http://twitter.com/search?q=%23AskTeesta', 'promoted_content': None, 'query': '%23AskTeesta', 'tweet_volume': None}, {'name': '#Ishaan', 'url': 'http://twitter.com/search?q=%23Ishaan', 'promoted_content': None, 'query': '%23Ishaan', 'tweet_volume': None}, {'name': '#JungaAudiofromJune13', 'url': 'http://twitter.com/search?q=%23JungaAudiofromJune13', 'promoted_content': None, 'query': '%23JungaAudiofromJune13', 'tweet_volume': None}, {'name': '#MumbaiDeluge', 'url': 'http://twitter.com/search?q=%23MumbaiDeluge', 'promoted_content': None, 'query': '%23MumbaiDeluge', 'tweet_volume': None}, {'name': '#KarHarMaidaanFateh', 'url': 'http://twitter.com/search?q=%23KarHarMaidaanFateh', 'promoted_content': None, 'query': '%23KarHarMaidaanFateh', 'tweet_volume': None}, {'name': '#Jayakumar', 'url': 'http://twitter.com/search?q=%23Jayakumar', 'promoted_content': None, 'query': '%23Jayakumar', 'tweet_volume': None}, {'name': '#SabseSmartKaun', 'url': 'http://twitter.com/search?q=%23SabseSmartKaun', 'promoted_content': None, 'query': '%23SabseSmartKaun', 'tweet_volume': None}, {'name': '#BookReview', 'url': 'http://twitter.com/search?q=%23BookReview', 'promoted_content': None, 'query': '%23BookReview', 'tweet_volume': None}, {'name': '#HeavyRain', 'url': 'http://twitter.com/search?q=%23HeavyRain', 'promoted_content': None, 'query': '%23HeavyRain', 'tweet_volume': None}, {'name': '#INDvKEN', ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#njdominion",
#     "url": "http://twitter.com/search?q=%23njdominion",
#     "promoted_content": null,
#     "query": "%23njdominion",
#     "tweet_volume": 34719
#    },
#    {
#     "name": "#FakeLove11thWin",
#     "url": "http://twitter.com/search?q=%23FakeLove11thWin",
#     "promoted_content": null,
#     "query": "%23FakeLove11thWin",
#     "tweet_volume": 216523
#    },
#    {
#     "name": "Swaggy P",
#     "url": "http://twitter.com/search?q=%22Swaggy+P%22",
#     "promoted_content": null,
#     "query": "%22Swaggy+P%22",
#     "tweet_volume": 39608
#    },
#    {
#     "name": "#BestThingAboutThe70s",
#     "url": "http://twitter.com/search?q=%23BestThingAboutThe70s",
#     "promoted_content": null,
#     "query": "%23BestThingAboutThe70s",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MoviesShownInHell",
#     "url": "http://twitter.com/search?q=%23MoviesShownInHell",
#     "promoted_content": null,
#     "query": "%23MoviesShownInHell",
#     "tweet_volume": null
#    },
#    {
#     "name": "#GoldenStateWarriors",
#     "url": "http://twitter.com/search?q=%23GoldenStateWarriors",
#     "promoted_content": null,
#     "query": "%23GoldenStateWarriors",
#     "tweet_volume": null
#    },
#    {
#     "name": "Fulton Co.",
#     "url": "http://twitter.com/search?q=%22Fulton+Co.%22",
#     "promoted_content": null,
#     "query": "%22Fulton+Co.%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Dubs",
#     "url": "http://twitter.com/search?q=Dubs",
#     "promoted_content": null,
#     "query": "Dubs",
#     "tweet_volume": 18283
#    },
#    {
#     "name": "Quinn Cook",
#     "url": "http://twitter.com/search?q=%22Quinn+Cook%22",
#     "promoted_content": null,
#     "query": "%22Quinn+Cook%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jordan Bell",
#     "url": "http://twitter.com/search?q=%22Jordan+Bell%22",
#     "promoted_content": null,
#     "query": "%22Jordan+Bell%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "David West",
#     "url": "http://twitter.com/search?q=%22David+West%22",
#     "promoted_content": null,
#     "query": "%22David+West%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "So Lebron",
#     "url": "http://twitter.com/search?q=%22So+Lebron%22",
#     "promoted_content": null,
#     "query": "%22So+Lebron%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Cavs in 8",
#     "url": "http://twitter.com/search?q=%22Cavs+in+8%22",
#     "promoted_content": null,
#     "query": "%22Cavs+in+8%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Melo",
#     "url": "http://twitter.com/search?q=Melo",
#     "promoted_content": null,
#     "query": "Melo",
#     "tweet_volume": 30532
#    },
#    {
#     "name": "Redmond O'Neal",
#     "url": "http://twitter.com/search?q=%22Redmond+O%27Neal%22",
#     "promoted_content": null,
#     "query": "%22Redmond+O%27Neal%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Anthony Bourdain",
#     "url": "http://twitter.com/search?q=%22Anthony+Bourdain%22",
#     "promoted_content": null,
#     "query": "%22Anthony+Bourdain%22",
#     "tweet_volume": 1853380
#    },
#    {
#     "name": "Kids See Ghosts",
#     "url": "http://twitter.com/search?q=%22Kids+See+Ghosts%22",
#     "promoted_content": null,
#     "query": "%22Kids+See+Ghosts%22",
#     "tweet_volume": 96320
#    },
#    {
#     "name": "Nick Young",
#     "url": "http://twitter.com/search?q=%22Nick+Young%22",
#     "promoted_content": null,
#     "query": "%22Nick+Young%22",
#     "tweet_volume": 38012
#    },
#    {
#     "name": "Charles Krauthammer",
#     "url": "http://twitter.com/search?q=%22Charles+Krauthammer%22",
#     "promoted_content": null,
#     "query": "%22Charles+Krauthammer%22",
#     "tweet_volume": 120862
#    },
#    {
#     "name": "Kitchen Confidential",
#     "url": "http://twitter.com/search?q=%22Kitchen+Confidential%22",
#     "promoted_content": null,
#     "query": "%22Kitchen+Confidential%22",
#     "tweet_volume": 18379
#    },
#    {
#     "name": "Muhammad Ali",
#     "url": "http://twitter.com/search?q=%22Muhammad+Ali%22",
#     "promoted_content": null,
#     "query": "%22Muhammad+Ali%22",
#     "tweet_volume": 121442
#    },
#    {
#     "name": "No Reservations",
#     "url": "http://twitter.com/search?q=%22No+Reservations%22",
#     "promoted_content": null,
#     "query": "%22No+Reservations%22",
#     "tweet_volume": 23828
#    },
#    {
#     "name": "Hereditary",
#     "url": "http://twitter.com/search?q=Hereditary",
#     "promoted_content": null,
#     "query": "Hereditary",
#     "tweet_volume": 23466
#    },
#    {
#     "name": "Stanley Cup",
#     "url": "http://twitter.com/search?q=%22Stanley+Cup%22",
#     "promoted_content": null,
#     "query": "%22Stanley+Cup%22",
#     "tweet_volume": 108185
#    },
#    {
#     "name": "First Man",
#     "url": "http://twitter.com/search?q=%22First+Man%22",
#     "promoted_content": null,
#     "query": "%22First+Man%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Ocean's 8",
#     "url": "http://twitter.com/search?q=%22Ocean%27s+8%22",
#     "promoted_content": null,
#     "query": "%22Ocean%27s+8%22",
#     "tweet_volume": 18050
#    },
#    {
#     "name": "Chris Sale",
#     "url": "http://twitter.com/search?q=%22Chris+Sale%22",
#     "promoted_content": null,
#     "query": "%22Chris+Sale%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FinalsMVP",
#     "url": "http://twitter.com/search?q=%23FinalsMVP",
#     "promoted_content": null,
#     "query": "%23FinalsMVP",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MuscularMovies",
#     "url": "http://twitter.com/search?q=%23MuscularMovies",
#     "promoted_content": null,
#     "query": "%23MuscularMovies",
#     "tweet_volume": null
#    },
#    {
#     "name": "#UluwatuCT",
#     "url": "http://twitter.com/search?q=%23UluwatuCT",
#     "promoted_content": null,
#     "query": "%23UluwatuCT",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TEDxKakumaCamp",
#     "url": "http://twitter.com/search?q=%23TEDxKakumaCamp",
#     "promoted_content": null,
#     "query": "%23TEDxKakumaCamp",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Paris7s",
#     "url": "http://twitter.com/search?q=%23Paris7s",
#     "promoted_content": null,
#     "query": "%23Paris7s",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NationalBestFriendsDay",
#     "url": "http://twitter.com/search?q=%23NationalBestFriendsDay",
#     "promoted_content": null,
#     "query": "%23NationalBestFriendsDay",
#     "tweet_volume": 273073
#    },
#    {
#     "name": "#WorldOceansDay",
#     "url": "http://twitter.com/search?q=%23WorldOceansDay",
#     "promoted_content": null,
#     "query": "%23WorldOceansDay",
#     "tweet_volume": 179821
#    },
#    {
#     "name": "#FridayFeeling",
#     "url": "http://twitter.com/search?q=%23FridayFeeling",
#     "promoted_content": null,
#     "query": "%23FridayFeeling",
#     "tweet_volume": 143383
#    },
#    {
#     "name": "#suicide",
#     "url": "http://twitter.com/search?q=%23suicide",
#     "promoted_content": null,
#     "query": "%23suicide",
#     "tweet_volume": 36085
#    },
#    {
#     "name": "#HalloweenMovie",
#     "url": "http://twitter.com/search?q=%23HalloweenMovie",
#     "promoted_content": null,
#     "query": "%23HalloweenMovie",
#     "tweet_volume": 79188
#    },
#    {
#     "name": "#FlashbackFriday",
#     "url": "http://twitter.com/search?q=%23FlashbackFriday",
#     "promoted_content": null,
#     "query": "%23FlashbackFriday",
#     "tweet_volume": 33148
#    },
#    {
#     "name": "#SubwaySeries",
#     "url": "http://twitter.com/search?q=%23SubwaySeries",
#     "promoted_content": null,
#     "query": "%23SubwaySeries",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Sense8",
#     "url": "http://twitter.com/search?q=%23Sense8",
#     "promoted_content": null,
#     "query": "%23Sense8",
#     "tweet_volume": 124748
#    },
#    {
#     "name": "#SelfieForJoel",
#     "url": "http://twitter.com/search?q=%23SelfieForJoel",
#     "promoted_content": null,
#     "query": "%23SelfieForJoel",
#     "tweet_volume": 207920
#    },
#    {
#     "name": "#MyDatingProfileSays",
#     "url": "http://twitter.com/search?q=%23MyDatingProfileSays",
#     "promoted_content": null,
#     "query": "%23MyDatingProfileSays",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2018-06-09T09:42:21Z",
#   "created_at": "2018-06-09T09:37:07Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['india'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','us','india']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# 사전투표,#ロックの日,#WannaOne1TheWorldinBKK,#ALDUBMusicOfOurHearts,#NZLvFRA,能見さん,#아무것도몰랐던_사퍼_뉴비시절,#NRLKnightsRoosters,#TEDxKakumaCamp,#AFLSaintsSwans,#NUBantulCINTARumi,#loveparkrun,#WorldGinDay,#اقدر_الان_اقول,#PESBUKERSRAMADANANTV25,#SaturdayKitchen,#IAD18,#TroopingtheColour,#LibrosConPiernas,#vvkorea_309,#njdominion,#AFLGiantsSuns,#Paris7s,ミュージックフェア,#ViratBeardInsurance,Northcote,Swaggy P,#rEDRugby,#FakeLove11thWin,#نخبه_العود_مرسيدس17,최코테,#FelizSábado,MUSIC FAIR,ドリス,#9HaziranDünyaDuaGünü,#N1CanalFiesta23,Ravi Pujari,#9giugno,#ロック好きにしか解けないクイズ,#DíadelaRegióndeMurcia,#cumartesi,#BanggaIndonesia,혜화역,#QUINTET,#GoldenStateWarriors,#혜화시위,#NotOurLastHunt,#PertaminaBareng2Mudik2018,#HappyBirthdaySonamKapoor,#QueensBirthdayHonours
# ('----------', 'us')
# #Sense8,#HalloweenMovie,#FinalsMVP,Fulton Co.,#TEDxKakumaCamp,#SubwaySeries,Dubs,Melo,Hereditary,Charles Krauthammer,Ocean's 8,#suicide,#WorldOceansDay,#UluwatuCT,Quinn Cook,Kids See Ghosts,#njdominion,Chris Sale,#Paris7s,#FridayFeeling,Muhammad Ali,#MuscularMovies,Swaggy P,So Lebron,#SelfieForJoel,Kitchen Confidential,#FakeLove11thWin,Anthony Bourdain,Cavs in 8,First Man,#BestThingAboutThe70s,#MoviesShownInHell,No Reservations,#FlashbackFriday,#NationalBestFriendsDay,Nick Young,#GoldenStateWarriors,Jordan Bell,#MyDatingProfileSays,David West,Stanley Cup,Redmond O'Neal
# ('----------', 'india')
# #Ishaan,#Qingdao,#Jayakumar,#AnthonyBourdain,#IAmwayForward,#SaturdayMotivation,#SSCResult2018,#BookReview,#HafizSaeed,#Aatagallu,#YahooMessenger,Sonia Gandhi,Shantaram Naik,#HeavyRain,#Quantico,#HappyBirthdaySonamKapoor,#JungaAudiofromJune13,#Suriya,#KuppathuRaja,#WorldOceansDay,#6DaysToRace3,#INDvKEN,#PranabAtRSS,#KarHarMaidaanFateh,#ViratBeardInsurance,#MumbaiDeluge,#Ghajinikanth,#ProtinexWithShubman,Rs 4.5,#FirstMan,Rajesh Bharti,#Kaala,Maria Bueno,Ravi Pujari,#SabseSmartKaun,#CHSE,#GameOfThrones,#INDvPAK,Umar Khalid,बिरसा मुंडा,#NaaNuvve,#AskTeesta,#ieWorld,#NBAFinals

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and India'))
print((trends_set['india'].intersection(trends_set['world'])))
# Out:
# ('==========', 'intersection of world and us')
# {'#FakeLove11thWin', '#GoldenStateWarriors', '#TEDxKakumaCamp', '#njdominion', '#Paris7s', 'Swaggy P'}
# ('==========', 'intersection of us and India')
# {'#ViratBeardInsurance', '#HappyBirthdaySonamKapoor', 'Ravi Pujari'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = '#ViratBeardInsurance' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=number)

statuses = search_results['statuses']

# %%
len(statuses)
print(statuses)
# Out:
# [{'created_at': 'Sat Jun 09 09:55:35 +0000 2018', 'id': 1005387927596068864, 'id_str': '1005387927596068864', 'text': "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'imVkohli', 'name': 'Virat Kohli', 'id': 71201743, 'id_str': '71201743', 'indices': [3, 12]}, {'screen_name': 'klrahul11', 'name': 'K L Rahul', 'id': 1469065189, 'id_str': '1469065189', 'indices': [62, 72]}, {'screen_name': 'buntysajdeh', 'name': 'Bunty Sajdeh', 'id': 122009148, 'id_str': '122009148', 'indices': [74, 86]}, {'screen_name': 'yuzi_chahal', 'name': 'Yuzvendra Chahal', 'id': 447977892, 'id_str': '447977892', 'indices': [88, 100]}, {'screen_name': 'y_umesh', 'name': 'Umesh Yaadav', 'id': 321866313, 'id_str': '321866313', 'indices': [102, 110]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 999227494979944448, 'id_str': '999227494979944448', 'name': 'Suraj Kumar', 'screen_name': 'SurajKu03303325', 'location': 'Raebareli ', 'description': 'I am student of the bsc ag#', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 32, 'friends_count': 38, 'listed_count': 0, 'created_at': 'Wed May 23 09:56:14 +0000 2018', 'favourites_count': 904, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 735, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/999275132123164673/gpvZdhe2_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/999275132123164673/gpvZdhe2_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/999227494979944448/1527080985', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Jun 09 07:37:36 +0000 2018', 'id': 1005353200059207680, 'id_str': '1005353200059207680', 'text': "The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time… https://t.co/WcN0SHt5tJ", 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'klrahul11', 'name': 'K L Rahul', 'id': 1469065189, 'id_str': '1469065189', 'indices': [48, 58]}, {'screen_name': 'buntysajdeh', 'name': 'Bunty Sajdeh', 'id': 122009148, 'id_str': '122009148', 'indices': [60, 72]}, {'screen_name': 'yuzi_chahal', 'name': 'Yuzvendra Chahal', 'id': 447977892, 'id_str': '447977892', 'indices': [74, 86]}, {'screen_name': 'y_umesh', 'name': 'Umesh Yaadav', 'id': 321866313, 'id_str': '321866313', 'indices': [88, 96]}], 'urls': [{'url': 'https://t.co/WcN0SHt5tJ', 'expanded_url': 'https://twitter.com/i/web/status/1005353200059207680', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_ ...

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 30

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ["RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'RT @yuzi_chahal: Just heard @imVkohli got his beard insured. The story between the legend and his beard continues! Always seen him protecti…',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'RT @Shreya51220015: #ViratBeardInsurance\n#कबीरप्रभुकीलीलाएँ \nकबीरजी ने सर्वानन्द को शास्त्रार्थ में पराजित किया और सर्वानन्द जी ने कबीर जी…',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  '#ViratBeardInsurance\nBJP की हालत JIO SIM की तरह हैं।सुविधाओं का लाभ सब ले रहे है लेकिन तारीफ करने मे शर्म आती हैं!\n😁😁😁',
#  '#ViratBeardInsurance\n#सृष्टिकर्ता_कबीर_परमात्मा\nजसलाई मानिसहरु संत तथा कवि भन्छन वास्तवमा उँहा नै पुर्ण परमात्मा क… https://t.co/3rPGExmDb5',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "#ViratBeardInsurance If u have the money give education to those who can't afford it or save farmers or something..Rich sucker!",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'RT @Setu744078: #ViratBeardInsurance\n#कबीरप्रभुकीलीलाएँ\nपरमेस्वर खुद एक जीवन यहां हमारीं तरह जीवन जी कर दिखाता है \nपरमेस्वर एक झोपड़ी में र…',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'RT @Sunil23950025: #ViratBeardInsurance\n#कबीरप्रभुकीलीलाएँ\n एक बार कबीर साहब को घोर दंड देने के लिए खूनी हाथी से कुचलने का प्रयास किया गया…',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'RT @Ramkish38054342: #ViratBeardInsurance हे भारत सभी मनुष्यों की श्रद्धा उनके अंतकरण के अनुरूप होती है यह पुरुष सद्दाम आए हैं इसलिए जो पु…',
#  'RT @Sunil23950025: #ViratBeardInsurance\n#कबीरप्रभुकीलीलाएँ\n एक बार स्वामी रामानंद  जी को अपना ग्रुप बनाने के लिए बालक रूप में गए थे और बहुत…',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'RT @Sunil23950025: #ViratBeardInsurance\n#कबीरप्रभुकीलीलाएँ\n एक बार स्वामी रामानंद  जी को अपना ग्रुप बनाने के लिए बालक रूप में गए थे और बहुत…',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @FinancialXpress: #ViratKohli gets his beard 'insured', @klrahul11 reveals secret by sharing leaked footage\n\n#ViratBeardInsurance \n\nhttp…",
#  'मुंबई में भारी बारिश के कारण जलजमाव, रेल एवं विमानन सेवाएं प्रभावित\nhttps://t.co/E0HfJg7eTu\n#Mumbai  #Rain… https://t.co/30LmDKzIJj',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'RT @OdishaNew: How Modi has failed as prime minister of India | Asia Times #Qingdao #INDvPAK #RaviPujari #SCOSummit #HappyBirthdaySonamKapo…',
#  '#KashmirAndQuds \n#Kashmir\n#KashmirBleeds\n#KashmirKillings\n#INDvPAK\n#Qingdao\n#HappyBirthdaySonamKapoor\n#SCOSummit… https://t.co/RP5Qm92u12',
#  '#ViratBeardInsurance\n#कबीरप्रभुकीलीलाएँ \nकबीरजी ने सर्वानन्द को शास्त्रार्थ में पराजित किया और सर्वानन्द जी ने कबीर… https://t.co/LT9W90OW8M',
#  'How Modi has failed as prime minister of India | Asia Times #Qingdao #INDvPAK #RaviPujari #SCOSummit… https://t.co/AQZS3jqSAs',
#  'विदेशो में घूमने व election में लोगो को झूठे वायदे कर देने से 2019 में बुरी तरह हारने जा रहे है मोदी साहब व राहुल… https://t.co/MgfSDVdg6R',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @FinancialXpress: #ViratKohli gets his beard 'insured', @klrahul11 reveals secret by sharing leaked footage\n\n#ViratBeardInsurance \n\nhttp…",
#  'Leaked footage of @imVkohli where you can see that Virat has insured his beard  #ViratBeardInsurance https://t.co/X6iBN4k8Dg',
#  "RT @NewsX: Twitterati go berserk over @imVkohli's insured beard news!\n#ViratBeardInsurance #ViratKohli \nhttps://t.co/rsZtxKPKTN",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'Yahan #Pakistan apne players ka insurance nahi karwa rahe Idhar @imVkohli beard ka karwa raha hai. #ViratBeardInsurance',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'RT @yuzi_chahal: Just heard @imVkohli got his beard insured. The story between the legend and his beard continues! Always seen him protecti…',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'RT @imakarsh17: That moment When you realise @imVkohli s beard is more famous than your existence #ViratBeardInsurance  @preksha420 https:/…',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'RT @oldschoolmonk: Poor people in India are not able to buy life and medical insurance and @imVkohli shamelessly showing off #ViratBeardIns…',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'RT @buntysajdeh: Hahaha what a Brilliant idea @imVkohli! 🤣 Shall we get a group discount? What say boys? @klrahul11 @yuzi_chahal @y_umesh #…',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'RT @yuzi_chahal: Just heard @imVkohli got his beard insured. The story between the legend and his beard continues! Always seen him protecti…',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @iampsisodia: #poll What will be in place of '?'\n4, 9, 13, 22, 35, ?\n\n🔃 Retweet if you know the answer\n🙏 Scroll down if you don't know i…",
#  'RT @lAkshaykumaar: जिस देश मे 22 पार्टियों का लक्ष्य सिर्फ मोदी जी को हराना है, \n\nउनसे विकास की उम्मीद सिर्फ बेवक़ूफ़ ही कर सकते हैं।\n\nRT-A…',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'RT @vGDa60w59BagH21: #ViratBeardInsurance\n#कबीरप्रभुकीलीलाएँ क्या आप जानते है आज से 600साल पहले कबीर परमेश्रर आऐ थे जिसे सारी दुनिया संत के…',
#  'RT @yuzi_chahal: Just heard @imVkohli got his beard insured. The story between the legend and his beard continues! Always seen him protecti…',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'दिल्ली सरकार ने जनवरी 2016 से पेट्रोल और डीजल पर नहीं बढ़ाए हैं वैट: सिसोदिया\nhttps://t.co/zyNxL4F5ar… https://t.co/JEuC8d0ZPL',
#  'RT @RatanSonawane3: #ViratBeardInsurance\n#कबीरप्रभुकीलीलाएँ जानिए क्या है सच साधना चैनल पर 7.30 से https://t.co/4Vv0uEnFOe',
#  'RT @yuzi_chahal: Just heard @imVkohli got his beard insured. The story between the legend and his beard continues! Always seen him protecti…',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'RT @yuzi_chahal: Just heard @imVkohli got his beard insured. The story between the legend and his beard continues! Always seen him protecti…',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'RT @oldschoolmonk: Poor people in India are not able to buy life and medical insurance and @imVkohli shamelessly showing off #ViratBeardIns…',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'RT @Sunil23950025: #ViratBeardInsurance\n#कबीरप्रभुकीलीलाएँ\n एक बार स्वामी रामानंद  जी को अपना ग्रुप बनाने के लिए बालक रूप में गए थे और बहुत…',
#  'RT @yuzi_chahal: Just heard @imVkohli got his beard insured. The story between the legend and his beard continues! Always seen him protecti…',
#  'RT @Ramkish38054342: #ViratBeardInsurance हे भारत सभी मनुष्यों की श्रद्धा उनके अंतकरण के अनुरूप होती है यह पुरुष सद्दाम आए हैं इसलिए जो पु…',
#  'RT @oldschoolmonk: Poor people in India are not able to buy life and medical insurance and @imVkohli shamelessly showing off #ViratBeardIns…',
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'RT @Sunil23950025: #ViratBeardInsurance\n#कबीरप्रभुकीलीलाएँ\n एक बार कबीर साहब को घोर दंड देने के लिए खूनी हाथी से कुचलने का प्रयास किया गया…',
#  'RT @Setu744078: #ViratBeardInsurance\n#कबीरप्रभुकीलीलाएँ\nपरमेस्वर खुद एक जीवन यहां हमारीं तरह जीवन जी कर दिखाता है \nपरमेस्वर एक झोपड़ी में र…',
#  "RT @NewsX: Twitterati go berserk over @imVkohli's insured beard news!\n#ViratBeardInsurance #ViratKohli \nhttps://t.co/rsZtxKPKTN",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys 😂 #Vi…",
#  'RT @yuzi_chahal: Just heard @imVkohli got his beard insured. The story between the legend and his beard continues! Always seen him protecti…',
#  'RT @CricCrazyNIKS: Stylish on and off the pitch, @imVkohli steps up his game by insuring his beard! #ViratBeardInsurance\nhttps://t.co/jE3LG…',
#  'RT @SushilKashyap01: In case you haven’t heard yet, @imVkohli just got his beard insured! Don’t believe us? Here’s a video of it all unfold…']

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Sat Jun 09 09:55:35 +0000 2018",
#  "id": 1005387927596068864,
#  "id_str": "1005387927596068864",
#  "text": "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys \ud83d\ude02 #Vi\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "imVkohli",
#     "name": "Virat Kohli",
#     "id": 71201743,
#     "id_str": "71201743",
#     "indices": [
#      3,
#      12
#     ]
#    },
#    {
#     "screen_name": "klrahul11",
#     "name": "K L Rahul",
#     "id": 1469065189,
#     "id_str": "1469065189",
#     "indices": [
#      62,
#      72
#     ]
#    },
#    {
#     "screen_name": "buntysajdeh",
#     "name": "Bunty Sajdeh",
#     "id": 122009148,
#     "id_str": "122009148",
#     "indices": [
#      74,
#      86
#     ]
#    },
#    {
#     "screen_name": "yuzi_chahal",
#     "name": "Yuzvendra Chahal",
#     "id": 447977892,
#     "id_str": "447977892",
#     "indices": [
#      88,
#      100
#     ]
#    },
#    {
#     "screen_name": "y_umesh",
#     "name": "Umesh Yaadav",
#     "id": 321866313,
#     "id_str": "321866313",
#     "indices": [
#      102,
#      110
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 999227494979944448,
#   "id_str": "999227494979944448",
#   "name": "Suraj Kumar",
#   "screen_name": "SurajKu03303325",
#   "location": "Raebareli ",
#   "description": "I am student of the bsc ag#",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 32,
#   "friends_count": 38,
#   "listed_count": 0,
#   "created_at": "Wed May 23 09:56:14 +0000 2018",
#   "favourites_count": 904,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 735,
#   "lang": "en",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "F5F8FA",
#   "profile_background_image_url": null,
#   "profile_background_image_url_https": null,
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/999275132123164673/gpvZdhe2_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/999275132123164673/gpvZdhe2_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/999227494979944448/1527080985",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Sat Jun 09 07:37:36 +0000 2018",
#   "id": 1005353200059207680,
#   "id_str": "1005353200059207680",
#   "text": "The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time\u2026 https://t.co/WcN0SHt5tJ",
#   "truncated": true,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "klrahul11",
#      "name": "K L Rahul",
#      "id": 1469065189,
#      "id_str": "1469065189",
#      "indices": [
#       48,
#       58
#      ]
#     },
#     {
#      "screen_name": "buntysajdeh",
#      "name": "Bunty Sajdeh",
#      "id": 122009148,
#      "id_str": "122009148",
#      "indices": [
#       60,
#       72
#      ]
#     },
#     {
#      "screen_name": "yuzi_chahal",
#      "name": "Yuzvendra Chahal",
#      "id": 447977892,
#      "id_str": "447977892",
#      "indices": [
#       74,
#       86
#      ]
#     },
#     {
#      "screen_name": "y_umesh",
#      "name": "Umesh Yaadav",
#      "id": 321866313,
#      "id_str": "321866313",
#      "indices": [
#       88,
#       96
#      ]
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/WcN0SHt5tJ",
#      "expanded_url": "https://twitter.com/i/web/status/1005353200059207680",
#      "display_url": "twitter.com/i/web/status/1\u2026",
#      "indices": [
#       116,
#       139
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 71201743,
#    "id_str": "71201743",
#    "name": "Virat Kohli",
#    "screen_name": "imVkohli",
#    "location": "",
#    "description": "The Official twitter account of Virat Kohli, Indian cricketer, gamer, car lover, loves soccer and an enthusiast.",
#    "url": "https://t.co/OhSih7EL7w",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/OhSih7EL7w",
#        "expanded_url": "https://instagram.com/virat.kohli",
#        "display_url": "instagram.com/virat.kohli",
#        "indices": [
#         0,
#         23
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 25448093,
#    "friends_count": 51,
#    "listed_count": 7099,
#    "created_at": "Thu Sep 03 07:57:30 +0000 2009",
#    "favourites_count": 174,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": true,
#    "verified": true,
#    "statuses_count": 1514,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "022330",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme15/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme15/bg.png",
#    "profile_background_tile": true,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/789817267567472640/BlpcUEvx_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/789817267567472640/BlpcUEvx_normal.jpg",
#    "profile_link_color": "0084B4",
#    "profile_sidebar_border_color": "FFFFFF",
#    "profile_sidebar_fill_color": "C0DFEC",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": true,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "regular"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 1217,
#   "favorite_count": 12440,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 1217,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]

#Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 1217
# False

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @imVkohli: The talk around my beard is quite entertaining. @klrahul11, @buntysajdeh, @yuzi_chahal, @y_umesh it's popcorn time boys \ud83d\ude02 #Vi\u2026",
#  "RT @yuzi_chahal: Just heard @imVkohli got his beard insured. The story between the legend and his beard continues! Always seen him protecti\u2026",
#  "RT @Shreya51220015: #ViratBeardInsurance\n#\u0915\u092c\u0940\u0930\u092a\u094d\u0930\u092d\u0941\u0915\u0940\u0932\u0940\u0932\u093e\u090f\u0901 \n\u0915\u092c\u0940\u0930\u091c\u0940 \u0928\u0947 \u0938\u0930\u094d\u0935\u093e\u0928\u0928\u094d\u0926 \u0915\u094b \u0936\u093e\u0938\u094d\u0924\u094d\u0930\u093e\u0930\u094d\u0925 \u092e\u0947\u0902 \u092a\u0930\u093e\u091c\u093f\u0924 \u0915\u093f\u092f\u093e \u0914\u0930 \u0938\u0930\u094d\u0935\u093e\u0928\u0928\u094d\u0926 \u091c\u0940 \u0928\u0947 \u0915\u092c\u0940\u0930 \u091c\u0940\u2026",
#  "#ViratBeardInsurance\nBJP \u0915\u0940 \u0939\u093e\u0932\u0924 JIO SIM \u0915\u0940 \u0924\u0930\u0939 \u0939\u0948\u0902\u0964\u0938\u0941\u0935\u093f\u0927\u093e\u0913\u0902 \u0915\u093e \u0932\u093e\u092d \u0938\u092c \u0932\u0947 \u0930\u0939\u0947 \u0939\u0948 \u0932\u0947\u0915\u093f\u0928 \u0924\u093e\u0930\u0940\u092b \u0915\u0930\u0928\u0947 \u092e\u0947 \u0936\u0930\u094d\u092e \u0906\u0924\u0940 \u0939\u0948\u0902!\n\ud83d\ude01\ud83d\ude01\ud83d\ude01",
#  "#ViratBeardInsurance\n#\u0938\u0943\u0937\u094d\u091f\u093f\u0915\u0930\u094d\u0924\u093e_\u0915\u092c\u0940\u0930_\u092a\u0930\u092e\u093e\u0924\u094d\u092e\u093e\n\u091c\u0938\u0932\u093e\u0908 \u092e\u093e\u0928\u093f\u0938\u0939\u0930\u0941 \u0938\u0902\u0924 \u0924\u0925\u093e \u0915\u0935\u093f \u092d\u0928\u094d\u091b\u0928 \u0935\u093e\u0938\u094d\u0924\u0935\u092e\u093e \u0909\u0901\u0939\u093e \u0928\u0948 \u092a\u0941\u0930\u094d\u0923 \u092a\u0930\u092e\u093e\u0924\u094d\u092e\u093e \u0915\u2026 https://t.co/3rPGExmDb5"
# ]
# [
#  "imVkohli",
#  "klrahul11",
#  "buntysajdeh",
#  "yuzi_chahal",
#  "y_umesh"
# ]
# [
#  "ViratBeardInsurance",
#  "\u0915\u092c\u0940\u0930\u092a\u094d\u0930\u092d\u0941\u0915\u0940\u0932\u0940\u0932\u093e\u090f\u0901",
#  "ViratBeardInsurance",
#  "ViratBeardInsurance",
#  "\u0938\u0943\u0937\u094d\u091f\u093f\u0915\u0930\u094d\u0924\u093e_\u0915\u092c\u0940\u0930_\u092a\u0930\u092e\u093e\u0924\u094d\u092e\u093e"
# ]
# [
#  "RT",
#  "@imVkohli:",
#  "The",
#  "talk",
#  "around"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('RT', 19), ('#ViratBeardInsurance', 17), ('beard', 9), ('में', 8), ('@imVkohli', 7), ('his', 7), ('#कबीरप्रभुकीलीलाएँ', 7), ('को', 6), ('है', 6), ('ने', 5)]
#
# [('imVkohli', 10), ('klrahul11', 3), ('yuzi_chahal', 3), ('buntysajdeh', 2), ('y_umesh', 2), ('Sunil23950025', 2), ('Shreya51220015', 1), ('Setu744078', 1), ('Ramkish38054342', 1), ('FinancialXpress', 1)]
#
# [('ViratBeardInsurance', 17), ('कबीरप्रभुकीलीलाएँ', 7), ('Qingdao', 3), ('INDvPAK', 3), ('SCOSummit', 3), ('ViratKohli', 2), ('RaviPujari', 2), ('सृष्टिकर्ता_कबीर_परमात्मा', 1), ('Mumbai', 1), ('Rain', 1)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# RT                   |     19
# #ViratBeardInsurance |     17
# beard                |      9
# में                  |      8
# @imVkohli            |      7
# his                  |      7
# #कबीरप्रभुकीलीलाएँ   |      7
# को                   |      6
# है                   |      6
# ने                   |      5
#
#     Screen Name      | Count
# ****************************************
# imVkohli             |     10
# klrahul11            |      3
# yuzi_chahal          |      3
# buntysajdeh          |      2
# y_umesh              |      2
# Sunil23950025        |      2
# Shreya51220015       |      1
# Setu744078           |      1
# Ramkish38054342      |      1
# FinancialXpress      |      1
#
#       Hashtag        | Count
# ****************************************
# ViratBeardInsurance  |     17
# कबीरप्रभुकीलीलाएँ    |      7
# Qingdao              |      3
# INDvPAK              |      3
# SCOSummit            |      3
# ViratKohli           |      2
# RaviPujari           |      2
# सृष्टिकर्ता_कबीर_परमात्मा |      1
# Mumbai               |      1
# Rain                 |      1

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
# Out:
#  Count  |   Screen Name   | Text
# ************************************************************
#  1217   |    imVkohli     | RT @imVkohli: The talk around my beard is quite en
#         |                 | tertaining. @klrahul11, @buntysajdeh, @yuzi_chahal
#         |                 | , @y_umesh it's popcorn time boys 😂 #Vi…
#   288   |   yuzi_chahal   | RT @yuzi_chahal: Just heard @imVkohli got his bear
#         |                 | d insured. The story between the legend and his be
#         |                 | ard continues! Always seen him protecti…
#   117   |     ANlTAJI     | RT @lAkshaykumaar: जिस देश मे 22 पार्टियों का लक्ष
#         |                 | ्य सिर्फ मोदी जी को हराना है, \\उनसे विकास की उम्म
#         |                 | ीद सिर्फ बेवक़ूफ़ ही कर सकते हैं।\\RT-A…
#   80    |   buntysajdeh   | RT @buntysajdeh: Hahaha what a Brilliant idea @imV
#         |                 | kohli! 🤣 Shall we get a group discount? What say b
#         |                 | oys? @klrahul11 @yuzi_chahal @y_umesh #…
#   80    | SushilKashyap01 | RT @SushilKashyap01: In case you haven’t heard yet
#         |                 | , @imVkohli just got his beard insured! Don’t beli
#         |                 | eve us? Here’s a video of it all unfold…
#   64    |  CricCrazyNIKS  | RT @CricCrazyNIKS: Stylish on and off the pitch, @
#         |                 | imVkohli steps up his game by insuring his beard!
#         |                 | #ViratBeardInsurance\https://t.co/jE3LG…
#   48    | FinancialXpress | RT @FinancialXpress: #ViratKohli gets his beard 'i
#         |                 | nsured', @klrahul11 reveals secret by sharing leak
#         |                 | ed footage\\#ViratBeardInsurance \\http…
#   32    |      NewsX      | RT @NewsX: Twitterati go berserk over @imVkohli's
#         |                 | insured beard news!\#ViratBeardInsurance #ViratKoh
#         |                 | li \https://t.co/rsZtxKPKTN
#    5    | Ramkish38054342 | RT @Ramkish38054342: #ViratBeardInsurance हे भारत
#         |                 | सभी मनुष्यों की श्रद्धा उनके अंतकरण के अनुरूप होती
#         |                 |  है यह पुरुष सद्दाम आए हैं इसलिए जो पु…
#    4    |  oldschoolmonk  | RT @oldschoolmonk: Poor people in India are not ab
#         |                 | le to buy life and medical insurance and @imVkohli
#         |                 |  shamelessly showing off #ViratBeardIns…
